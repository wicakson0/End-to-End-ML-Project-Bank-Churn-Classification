# %% [markdown]
# # Testing Pipelines

# %% [markdown]
# ## Loading Pipeline

# %%
import joblib
import pandas as pd

# %%
pipeline = joblib.load('20240219203143.pkl')

# %% [markdown]
# ## Loading Test Data

# %%
path = '../data/Churn_Modelling.csv'

# %%
churn = pd.read_csv(path)
churn = churn.set_index('CustomerId')
churn = churn.drop('RowNumber', axis=1)
churn = churn.drop_duplicates()
churn
# Out:
#               Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15634602     Hargrave          619    France  Female  42.0       2       0.00
# 15647311         Hill          608     Spain  Female  41.0       1   83807.86
# 15619304         Onio          502    France  Female  42.0       8  159660.80
# 15701354         Boni          699    France  Female  39.0       1       0.00
# 15737888     Mitchell          850     Spain  Female  43.0       2  125510.82
# ...               ...          ...       ...     ...   ...     ...        ...
# 15606229     Obijiaku          771    France    Male  39.0       5       0.00
# 15569892    Johnstone          516    France    Male  35.0      10   57369.61
# 15584532          Liu          709    France  Female  36.0       7       0.00
# 15682355    Sabbatini          772   Germany    Male  42.0       3   75075.31
# 15628319       Walker          792    France  Female  28.0       4  130142.79
#
# ...

# %%
churn.iloc[0:5, :-1]
# Out:
#              Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15634602    Hargrave          619    France  Female  42.0       2       0.00
# 15647311        Hill          608     Spain  Female  41.0       1   83807.86
# 15619304        Onio          502    France  Female  42.0       8  159660.80
# 15701354        Boni          699    France  Female  39.0       1       0.00
# 15737888    Mitchell          850     Spain  Female  43.0       2  125510.82
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# CustomerId
# 15634602                1        1.0             1.0        101348.88
# 15647311                1        0.0             1.0        112542.58
# 15619304                3        1.0             0.0        113931.57
# 15701354                2        0.0             0.0         93826.63
# 15737888                1        NaN             1.0         79084.10

# %%
churn.iloc[0, :-1]
# Out:
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                     42.0
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                1.0
# IsActiveMember           1.0
# EstimatedSalary    101348.88
# Name: 15634602, dtype: object

# %%
pred_proba = pipeline.predict_proba(churn.iloc[0:5, :-1])
pred_proba
# Out:
# array([[0.06636359, 0.93363641],
#        [0.65611052, 0.34388948],
#        [0.00714434, 0.99285566],
#        [0.86113434, 0.13886566],
#        [0.85097668, 0.14902332]])

# %%
pred_discrete = pipeline.predict(pd.DataFrame(churn.iloc[0, :-1]))
pred_discrete
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pred_discrete = pipeline.predict(pd.DataFrame(churn.iloc[0, :-1]))
#       2 pred_discrete
#
# File E:\Current_Workdir\Portfolios\End-to-End-Machine-Learning-Project-Bank-Churn-Prediction\.venv\Lib\site-packages\sklearn\pipeline.py:602, in Pipeline.predict(self, X, **params)
#     600 if not _routing_enabled():
#     601     for _, name, transform in self._iter(with_final=False):
# --> 602         Xt = transform.transform(Xt)
#     603     return self.steps[-1][1].predict(Xt, **params)
#     605 # metadata routing enabled
#
# File E:\Current_Workdir\Portfolios\End-to-End-Machine-Learning-Project-Bank-Churn-Prediction\.venv\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
# ...

# %%
columns = ['Surname',
               'CreditScore',
               'Geography',
               'Gender',
               'Age',
               'Tenure',
               'Balance',
               'NumOfProducts',
               'HasCrCard',
               'IsActiveMember',
               'EstimatedSalary']

# %%
test_row = pd.DataFrame([["Hargrave", 619, "France", "Female", 42, 2, 0, 1, 1, 1, 101348]],  columns = columns)
test_row
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure  Balance  \
# 0  Hargrave          619    France  Female   42       2        0
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0              1          1               1           101348

# %%
pipeline.predict(test_row)[0]
# Out:
# 1

# %%
input_dict = {
        'Surname': ["Hargrave"], 
        'CreditScore': [619], 
        'Geography': ["France"],
        'Gender': ["Female"],
        'Age': [42],
        'Tenure': [2],
        'Balance': [0],
        'NumOfProducts': [1],
        'HasCrCard': [1],
        'IsActiveMember': [1],
        'EstimatedSalary': [101348]
    }
    
input_df = pd.DataFrame(input_dict)
input_df
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure  Balance  \
# 0  Hargrave          619    France  Female   42       2        0
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0              1          1               1           101348

# %%
pipeline.predict(input_df)[0]
# Out:
# 1
